# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.1, 10, 0.01)
y = [1./i for i in x]

plt.plot(x, y)

ax = plt.gca()

ax.set_xticks([])
ax.set_yticks([])

plt.xlabel('Performance')
plt.ylabel('Portability')
plt.savefig('performance_portability.svg')
# Out:
# Text(0, 0.5, 'Portability')
